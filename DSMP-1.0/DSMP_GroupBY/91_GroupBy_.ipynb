# %%
import pandas as pd
import numpy as np

df = pd.read_csv("IMDB top 1000.csv")
df.shape
# Out:
# (1000, 10)

# %%
df.head(1)
# Out:
#    Unnamed: 0                               Title Certificate Duration  Genre  \
# 0           0  1. The Shawshank Redemption (1994)           R  142 min  Drama
#
#    Rate  Metascore                                        Description  \
# 0   9.3       80.0  Two imprisoned men bond over a number of years...
#
#                                                 Cast  \
# 0  Director: Frank Darabont | Stars: Tim Robbins,...
#
#                                 Info
# 0  Votes: 2,295,987 | Gross: $28.34M

# %%
# Top 3 generes types movies that earn lots revenue

genre = df.groupby("Genre")
genre.sum()["Info"].sort_values(ascending=False).head(3)   #
genre["Info"].sum().sort_values(ascending=False).head(3)   # this is more better phle column then sum
# Out:
# Genre
# Biography, Crime, Drama     Votes: 999,623 | Gross: $46.84MVotes: 1,152,70...
# Action, Crime, Thriller     Votes: 983,871 | Gross: $70.10MVotes: 112,723 ...
# Crime, Mystery, Thriller    Votes: 975,320 | Gross: $23.34MVotes: 140,682 ...
# Name: Info, dtype: object

# %%
df.groupby("Genre")["Rate"].mean().sort_values(ascending=False).head(10)
# Out:
# Genre
# Drama, Family, Fantasy          8.600000
# Action, Sci-Fi                  8.600000
# Crime, Drama, Fantasy           8.600000
# Western                         8.533333
# Horror, Mystery, Thriller       8.500000
# Animation, Drama, War           8.500000
# Drama, Romance, War             8.500000
# Drama, Musical                  8.500000
# Animation, Adventure, Family    8.400000
# Animation, Drama, Fantasy       8.400000
# Name: Rate, dtype: float64

# %%
# Top directors with high metascores 

df.groupby("Cast")["Metascore"].sum().sort_values(ascending=False).head(3)
# Out:
# Cast
# Directors: Victor Fleming, George Cukor, Sam Wood | Stars: Clark Gable, Vivien Leigh, Thomas Mitchell, Barbara O'Neil    679.0
# Director: Carol Reed | Stars: Orson Welles, Joseph Cotten, Alida Valli, Trevor Howard                                    679.0
# Director: Ernst Lubitsch | Stars: Margaret Sullavan, James Stewart, Frank Morgan, Joseph Schildkraut                     672.0
# Name: Metascore, dtype: float64

# %%
df.groupby("Genre")["Rate"].max().sort_values(ascending=False).head(5)
# Out:
# Genre
# Drama                        9.3
# Crime, Drama                 9.2
# Action, Crime, Drama         9.0
# Biography, Drama, History    8.9
# Action, Adventure, Drama     8.9
# Name: Rate, dtype: float64

# %%
df.groupby("Cast")["Metascore"].count().sort_values(ascending=False).head(5)
# df.value_counts("Cast").sort_values(ascending=False)
# Out:
# Cast
# Director: Martin Campbell | Stars: Daniel Craig, Eva Green, Judi Dench, Jeffrey Wright                    7
# Director: Hirokazu Koreeda | Stars: Lily Franky, Sakura Andô, Kirin Kiki, Mayu Matsuoka                   7
# Director: Darren Aronofsky | Stars: Natalie Portman, Mila Kunis, Vincent Cassel, Winona Ryder             7
# Director: Garth Davis | Stars: Dev Patel, Nicole Kidman, Rooney Mara, Sunny Pawar                         7
# Director: Thomas Vinterberg | Stars: Ulrich Thomsen, Henning Moritzen, Thomas Bo Larsen, Paprika Steen    7
# Name: Metascore, dtype: int64

# %%
len(df.groupby("Genre"))
# df.groupby("Genre").nunique()
# Out:
# 130

# %%
# Returns Row from each 

df.groupby("Genre").size()
# Out:
# Genre
# Action, Adventure              4
# Action, Adventure, Comedy     29
# Action, Adventure, Drama      13
# Action, Adventure, Fantasy    10
# Action, Adventure, Sci-Fi     12
#                               ..
# Horror, Sci-Fi                 1
# Mystery, Romance, Thriller     1
# Mystery, Sci-Fi, Thriller      7
# Mystery, Thriller              4
# Western                        3
# Length: 130, dtype: int64

# %%
 
# df.groupby("Genre").first(5) 
# df.groupby("Genre").last(5) 
df.groupby("Genre").nth(5)
# Out:
#      Unnamed: 0                                              Title  \
# 53           53                               54. Capernaum (2018)
# 58           58                       59. Avengers: Endgame (2019)
# 70           70             71. Once Upon a Time in America (1984)
# 155         155                               156. Downfall (2004)
# 160         160                      161. L.A. Confidential (1997)
# 161         161                             162. The Bandit (1996)
# 178         178                  179. Judgment at Nuremberg (1961)
# 226         226                            229. Elite Squad (2007)
# 236         236                         239. Dil Chahta Hai (2001)
# 238         238                           241. Finding Nemo (2003)
# 248         248                   251. In the Mood for Love (2000)
# 309         309           312. Mr. Smith Goes to Washington (1939)
# 352         352                           355. The Avengers (2012)
# ...

# %%
df.groupby("Genre").get_group("Drama")
# Out:
#      Unnamed: 0                                       Title Certificate  \
# 0             0          1. The Shawshank Redemption (1994)           R
# 9             9                       10. Fight Club (1999)           R
# 18           18  19. One Flew Over the Cuckoo's Nest (1975)           R
# 39           39               40. American History X (1998)           R
# 44           44                  45. Cinema Paradiso (1988)           R
# ..          ...                                         ...         ...
# 984         984                 387. The Celebration (1998)           R
# 985         985                 388. Central Station (1998)           R
# 988         988                     391. Sling Blade (1996)           R
# 995         995                398. Scent of a Woman (1992)           R
# 998         998               301. Nights of Cabiria (1957)   Not Rated
#
#     Duration  Genre  Rate  Metascore  \
# 0    142 min  Drama   9.3       80.0
# ...

# %%
df.groupby("Genre").sample(2,replace=True)
# Out:
#      Unnamed: 0                                      Title Certificate  \
# 153         153                  154. Batman Begins (2005)       PG-13
# 153         153                  154. Batman Begins (2005)       PG-13
# 423         423              326. Bajrangi Bhaijaan (2015)   Not Rated
# 335         335        338. Guardians of the Galaxy (2014)       PG-13
# 439         439                   342. The Revenant (2015)           R
# ..          ...                                        ...         ...
# 990         990                     393. 12 Monkeys (1995)           R
# 215         215                        218. Kahaani (2012)   Not Rated
# 79           79                     80. Rear Window (1954)          PG
# 48           48    49. Once Upon a Time in the West (1968)       PG-13
# 12           12  13. The Good, the Bad and the Ugly (1966)           R
#
#     Duration                      Genre  Rate  Metascore  \
# ...

# %%
df.groupby("Genre").nunique()
# Out:
#                             Unnamed: 0  Title  Certificate  Duration  Rate  \
# Genre
# Action, Adventure                    4      4            2         4     2
# Action, Adventure, Comedy           29      5            4         5     3
# Action, Adventure, Drama            13      7            3         7     7
# Action, Adventure, Fantasy          10      4            2         4     4
# Action, Adventure, Sci-Fi           12      6            2         6     5
# ...                                ...    ...          ...       ...   ...
# Horror, Sci-Fi                       1      1            1         1     1
# Mystery, Romance, Thriller           1      1            1         1     1
# Mystery, Sci-Fi, Thriller            7      1            1         1     1
# Mystery, Thriller                    4      4            3         4     3
# Western                              3      3            2         3     3
#
# ...

# %%
# Diff aggregate function in diff 

df.groupby("Genre").agg({
    "Duration" : ["max" , 'min'],
    "Rate" : "mean",
    "Info" : "sum",
})
# Out:
#                            Duration               Rate  \
#                                 max      min      mean
# Genre
# Action, Adventure           164 min  115 min  8.300000
# Action, Adventure, Comedy    67 min  108 min  8.031034
# Action, Adventure, Drama    207 min  155 min  8.300000
# Action, Adventure, Fantasy  143 min  121 min  8.160000
# Action, Adventure, Sci-Fi   149 min  120 min  8.141667
# ...                             ...      ...       ...
# Horror, Sci-Fi              117 min  117 min  8.400000
# Mystery, Romance, Thriller  128 min  128 min  8.300000
# Mystery, Sci-Fi, Thriller   129 min  129 min  8.000000
# Mystery, Thriller           138 min  112 min  8.275000
# Western                     178 min  132 min  8.533333
#
#                                                                          Info
#                                                                           sum
# Genre
# ...

# %%
# df.groupby("Genre").agg(["max" , "min" ])

# %%
df
# Out:
#      Unnamed: 0                                              Title  \
# 0             0                 1. The Shawshank Redemption (1994)
# 1             1                            2. The Godfather (1972)
# 2             2                          3. The Dark Knight (2008)
# 3             3                   4. The Godfather: Part II (1974)
# 4             4  5. The Lord of the Rings: The Return of the Ki...
# ..          ...                                                ...
# 995         995                       398. Scent of a Woman (1992)
# 996         996                                399. Aladdin (1992)
# 997         997                                    400. JFK (1991)
# 998         998                      301. Nights of Cabiria (1957)
# 999         999                        302. Throne of Blood (1957)
#
#     Certificate Duration                         Genre  Rate  Metascore  \
# 0             R  142 min                         Drama   9.3       80.0
# ...

# %%
def rank_movie(grp):
    grp["Rank"] = grp["Rate"].rank(ascending=False)
    return grp

# %%
df.groupby("Genre").apply(rank_movie)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_4272\2596158729.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df.groupby("Genre").apply(rank_movie)
#                                Unnamed: 0  \
# Genre
# Action, Adventure         62           62
#                           71           71
#                           153         153
#                           166         166
# Action, Adventure, Comedy 173         173
# ...                                   ...
# Mystery, Thriller         144         144
#                           215         215
# Western                   12           12
#                           48           48
#                           115         115
#
# ...

# %%
duo = df.groupby(["Metascore","Duration"])
duo.size()
duo.get_group((61.0, "140 min"))
# Out:
# Metascore  Duration
# 61.0       140 min     7
#            189 min     1
# 62.0       119 min     1
#            132 min     1
#            146 min     7
#                       ..
# 100.0      175 min     1
#            188 min     1
#            228 min     1
#            96 min      1
#            99 min      1
# Length: 277, dtype: int64

# %%
# ACTor Genere combo

# %%
# All Balls thrown in ipl dataset can b done using groupny

# %%
ball = pd.read_csv('ball_by_ball_ipl.csv')

# %%
ball.shape
# Out:
# (239693, 35)

# %%
ball.groupby("Batter")["Runs From Ball"].sum().sort_values(ascending=False).head(10)
# Out:
# Batter
# V Kohli           7384
# S Dhawan          6914
# DA Warner         6628
# RG Sharma         6385
# SK Raina          5754
# MS Dhoni          5334
# RV Uthappa        5233
# CH Gayle          5203
# AB de Villiers    5162
# KD Karthik        4600
# Name: Runs From Ball, dtype: int64

# %%
ball.columns
# Out:
# Index(['Unnamed: 0', 'Match ID', 'Date', 'Venue', 'Bat First', 'Bat Second',
#        'Innings', 'Over', 'Ball', 'Batter', 'Non Striker', 'Bowler',
#        'Batter Runs', 'Extra Runs', 'Runs From Ball', 'Ball Rebowled',
#        'Extra Type', 'Wicket', 'Method', 'Player Out', 'Innings Runs',
#        'Innings Wickets', 'Target Score', 'Runs to Get', 'Balls Remaining',
#        'Winner', 'Chased Successfully', 'Total Batter Runs',
#        'Total Non Striker Runs', 'Batter Balls Faced',
#        'Non Striker Balls Faced', 'Player Out Runs', 'Player Out Balls Faced',
#        'Bowler Runs Conceded', 'Valid Ball'],
#       dtype='object')

# %%
ball[ball["Runs From Ball"] == 6]
# Out:
#         Unnamed: 0  Match ID        Date                               Venue  \
# 10              10   1359507  2023-04-23                        Eden Gardens
# 17              17   1359507  2023-04-23                        Eden Gardens
# 22              22   1359507  2023-04-23                        Eden Gardens
# 33              33   1359507  2023-04-23                        Eden Gardens
# 41              41   1359507  2023-04-23                        Eden Gardens
# ...            ...       ...         ...                                 ...
# 239604      239604   1136596  2018-05-05  Rajiv Gandhi International Stadium
# 239606      239606   1136596  2018-05-05  Rajiv Gandhi International Stadium
# 239667      239667   1136596  2018-05-05  Rajiv Gandhi International Stadium
# 239681      239681   1136596  2018-05-05  Rajiv Gandhi International Stadium
# 239689      239689   1136596  2018-05-05  Rajiv Gandhi International Stadium
#
# ...

# %%
ball[ball["Runs From Ball"] == 6].groupby("Batter")["Batter"].count().sort_values(ascending=False).head(10)
# Out:
# Batter
# CH Gayle          343
# RG Sharma         254
# AB de Villiers    242
# MS Dhoni          236
# V Kohli           229
# DA Warner         221
# KA Pollard        210
# SK Raina          201
# SR Watson         188
# AD Russell        186
# Name: Batter, dtype: int64

# %%
ball.columns
# Out:
# Index(['Unnamed: 0', 'Match ID', 'Date', 'Venue', 'Bat First', 'Bat Second',
#        'Innings', 'Over', 'Ball', 'Batter', 'Non Striker', 'Bowler',
#        'Batter Runs', 'Extra Runs', 'Runs From Ball', 'Ball Rebowled',
#        'Extra Type', 'Wicket', 'Method', 'Player Out', 'Innings Runs',
#        'Innings Wickets', 'Target Score', 'Runs to Get', 'Balls Remaining',
#        'Winner', 'Chased Successfully', 'Total Batter Runs',
#        'Total Non Striker Runs', 'Batter Balls Faced',
#        'Non Striker Balls Faced', 'Player Out Runs', 'Player Out Balls Faced',
#        'Bowler Runs Conceded', 'Valid Ball'],
#       dtype='object')

# %%
last = ball[ball["Over"] > 15]

last[( last["Runs From Ball"] == 6 )| (last["Runs From Ball"]== 4)]
# Out:
#         Unnamed: 0  Match ID        Date                               Venue  \
# 91              91   1359507  2023-04-23                        Eden Gardens
# 97              97   1359507  2023-04-23                        Eden Gardens
# 103            103   1359507  2023-04-23                        Eden Gardens
# 105            105   1359507  2023-04-23                        Eden Gardens
# 109            109   1359507  2023-04-23                        Eden Gardens
# ...            ...       ...         ...                                 ...
# 239667      239667   1136596  2018-05-05  Rajiv Gandhi International Stadium
# 239681      239681   1136596  2018-05-05  Rajiv Gandhi International Stadium
# 239683      239683   1136596  2018-05-05  Rajiv Gandhi International Stadium
# 239689      239689   1136596  2018-05-05  Rajiv Gandhi International Stadium
# 239690      239690   1136596  2018-05-05  Rajiv Gandhi International Stadium
#
# ...

# %%
last.groupby("Batter")["Batter"].count().sort_values(ascending=False).head(10)
# Out:
# Batter
# MS Dhoni          1876
# KA Pollard        1229
# RA Jadeja         1085
# KD Karthik         987
# RG Sharma          851
# AB de Villiers     849
# V Kohli            756
# HH Pandya          751
# YK Pathan          732
# AT Rayudu          725
# Name: Batter, dtype: int64

# %%
filter1 = ball[ball["Batter"] == "KL Rahul"]
filter1.groupby("Wicket")["Runs From Ball"].sum().reset_index()
# Out:
#    Wicket  Runs From Ball
# 0       0            4215
# 1       1               0

# %%
ball.columns
# Out:
# Index(['Unnamed: 0', 'Match ID', 'Date', 'Venue', 'Bat First', 'Bat Second',
#        'Innings', 'Over', 'Ball', 'Batter', 'Non Striker', 'Bowler',
#        'Batter Runs', 'Extra Runs', 'Runs From Ball', 'Ball Rebowled',
#        'Extra Type', 'Wicket', 'Method', 'Player Out', 'Innings Runs',
#        'Innings Wickets', 'Target Score', 'Runs to Get', 'Balls Remaining',
#        'Winner', 'Chased Successfully', 'Total Batter Runs',
#        'Total Non Striker Runs', 'Batter Balls Faced',
#        'Non Striker Balls Faced', 'Player Out Runs', 'Player Out Balls Faced',
#        'Bowler Runs Conceded', 'Valid Ball'],
#       dtype='object')
