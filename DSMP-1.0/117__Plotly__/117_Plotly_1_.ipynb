# %%
import pandas as pd
import numpy as np
import seaborn as sns
import plotly.graph_objects as go
import plotly.express as px

# %%
tips = px.data.tips()
iris = px.data.iris()
gap = px.data.gapminder()

# %%
gap
# Out:
#           country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# ...

# %%
# Scatterplot using go

temp = gap[gap["year"] == 2007 ]

# %%
trace1 = go.Scatter(x = temp["lifeExp"] , y = temp["gdpPercap"] , mode="markers")
trace2 = go.Scatter(x = [0,60,2] , y = [95,66,20555] , mode="lines")

data = [trace1 , trace2]

layout = go.Layout(title="Life Exp VS GDP per capita 2007 " , xaxis={"title":"Life Exp"} , yaxis={"title" : "GDP"})
fig = go.Figure(data,layout)
fig.show()

# %%
temp
# Out:
#                  country continent  year  lifeExp       pop     gdpPercap  \
# 11           Afghanistan      Asia  2007   43.828  31889923    974.580338
# 23               Albania    Europe  2007   76.423   3600523   5937.029526
# 35               Algeria    Africa  2007   72.301  33333216   6223.367465
# 47                Angola    Africa  2007   42.731  12420476   4797.231267
# 59             Argentina  Americas  2007   75.320  40301927  12779.379640
# ...                  ...       ...   ...      ...       ...           ...
# 1655             Vietnam      Asia  2007   74.249  85262356   2441.576404
# 1667  West Bank and Gaza      Asia  2007   73.422   4018332   3025.349798
# 1679         Yemen, Rep.      Asia  2007   62.698  22211743   2280.769906
# 1691              Zambia    Africa  2007   42.384  11746035   1271.211593
# 1703            Zimbabwe    Africa  2007   43.487  12311143    469.709298
#
#      iso_alpha  iso_num
# 11         AFG        4
# 23         ALB        8
# ...

# %%
# Using plotyl express

# %%
px.scatter(temp , x = "lifeExp" , y = "gdpPercap" , color="continent" , size="pop" , size_max = 50 ,hover_name="country")

# %%
px.scatter(gap , 
           x = "lifeExp" , 
           y = "gdpPercap" , 
           color="continent" ,
           size="pop" , 
           size_max = 50 ,
           hover_name="country" ,
            animation_frame="year",
           animation_group="country",
           range_x=[30,90]
          )

# %%
india = gap[gap["country"] == "India"]
india
# Out:
#     country continent  year  lifeExp         pop    gdpPercap iso_alpha  \
# 696   India      Asia  1952   37.373   372000000   546.565749       IND
# 697   India      Asia  1957   40.249   409000000   590.061996       IND
# 698   India      Asia  1962   43.605   454000000   658.347151       IND
# 699   India      Asia  1967   47.193   506000000   700.770611       IND
# 700   India      Asia  1972   50.651   567000000   724.032527       IND
# 701   India      Asia  1977   54.208   634000000   813.337323       IND
# 702   India      Asia  1982   56.596   708000000   855.723538       IND
# 703   India      Asia  1987   58.553   788000000   976.512676       IND
# 704   India      Asia  1992   60.223   872000000  1164.406809       IND
# 705   India      Asia  1997   61.765   959000000  1458.817442       IND
# 706   India      Asia  2002   62.879  1034172547  1746.769454       IND
# 707   India      Asia  2007   64.698  1110396331  2452.210407       IND
#
#      iso_num
# 696      356
# ...

# %%
px.line(
    india,
    x = "year",
    y = "pop",
    title="India Population from 1952 to 2007 "
)

# %%
# Get 3 items from pd

gap[gap["country"].isin(["India" , "Pakistan" , "China"])]

# Life exp me sabhi ka data h

# Long se Wide = Pivot
# Wide se Long = melt
# Out:
#        country continent  year   lifeExp         pop    gdpPercap iso_alpha  \
# 288      China      Asia  1952  44.00000   556263527   400.448611       CHN
# 289      China      Asia  1957  50.54896   637408000   575.987001       CHN
# 290      China      Asia  1962  44.50136   665770000   487.674018       CHN
# 291      China      Asia  1967  58.38112   754550000   612.705693       CHN
# 292      China      Asia  1972  63.11888   862030000   676.900092       CHN
# 293      China      Asia  1977  63.96736   943455000   741.237470       CHN
# 294      China      Asia  1982  65.52500  1000281000   962.421381       CHN
# 295      China      Asia  1987  67.27400  1084035000  1378.904018       CHN
# 296      China      Asia  1992  68.69000  1164970000  1655.784158       CHN
# 297      China      Asia  1997  70.42600  1230075000  2289.234136       CHN
# 298      China      Asia  2002  72.02800  1280400000  3119.280896       CHN
# ...

# %%
# Get 3 items from pd

gap[gap["country"].isin(["India" , "Pakistan" , "China"])].pivot(index="year" ,  columns="country" , values="lifeExp").melt()

# Long se Wide = Pivot
# Wide se Long = melt
# Out:
#      country     value
# 0      China  44.00000
# 1      China  50.54896
# 2      China  44.50136
# 3      China  58.38112
# 4      China  63.11888
# 5      China  63.96736
# 6      China  65.52500
# 7      China  67.27400
# 8      China  68.69000
# 9      China  70.42600
# 10     China  72.02800
# 11     China  72.96100
# 12     India  37.37300
# 13     India  40.24900
# 14     India  43.60500
# 15     India  47.19300
# 16     India  50.65100
# 17     India  54.20800
# 18     India  56.59600
# 19     India  58.55300
# 20     India  60.22300
# 21     India  61.76500
# 22     India  62.87900
# 23     India  64.69800
# 24  Pakistan  43.43600
# 25  Pakistan  45.55700
# 26  Pakistan  47.67000
# 27  Pakistan  49.80000
# 28  Pakistan  51.92900
# 29  Pakistan  54.04300
# 30  Pakistan  56.15800
# 31  Pakistan  58.24500
# 32  Pakistan  60.83800
# 33  Pakistan  61.81800
# 34  Pakistan  63.61000
# 35  Pakistan  65.48300

# %%
# Get 3 items from pd

temp = gap[gap["country"].isin(["India" , "Pakistan" , "China"])].pivot(index="year" ,  columns="country" , values="lifeExp")
temp
# Long se Wide = Pivot
# Wide se Long = melt
# Out:
# country     China   India  Pakistan
# year
# 1952     44.00000  37.373    43.436
# 1957     50.54896  40.249    45.557
# 1962     44.50136  43.605    47.670
# 1967     58.38112  47.193    49.800
# 1972     63.11888  50.651    51.929
# 1977     63.96736  54.208    54.043
# 1982     65.52500  56.596    56.158
# 1987     67.27400  58.553    58.245
# 1992     68.69000  60.223    60.838
# 1997     70.42600  61.765    61.818
# 2002     72.02800  62.879    63.610
# 2007     72.96100  64.698    65.483

# %%
px.line(
    temp,
    x = temp.index,
    y = temp.columns
)

# %% [markdown]
# # Barchart

# %%
df= gap[gap["country"] == "India"]
px.bar(
    df ,
    x = "year",
    y = "pop"
)

# %%
# Get 3 items from pd

temp = gap[gap["country"].isin(["India" , "Pakistan" , "China"])].pivot(index="year" ,  columns="country" , values="gdpPercap")
temp
# Long se Wide = Pivot
# Wide se Long = melt
# Out:
# country        China        India     Pakistan
# year
# 1952      400.448611   546.565749   684.597144
# 1957      575.987001   590.061996   747.083529
# 1962      487.674018   658.347151   803.342742
# 1967      612.705693   700.770611   942.408259
# 1972      676.900092   724.032527  1049.938981
# 1977      741.237470   813.337323  1175.921193
# 1982      962.421381   855.723538  1443.429832
# 1987     1378.904018   976.512676  1704.686583
# 1992     1655.784158  1164.406809  1971.829464
# 1997     2289.234136  1458.817442  2049.350521
# 2002     3119.280896  1746.769454  2092.712441
# 2007     4959.114854  2452.210407  2605.947580

# %%
px.bar(
    temp,
    x=temp.index,
    y=temp.columns,
    barmode="group"
)

# %%
# Get 3 items from pd

temp = gap[gap["country"].isin(["India" , "Pakistan" , "China"])].pivot(index="year" ,  columns="country" , values="pop")
temp

px.bar(
    temp,
    x=temp.index,
    y=temp.columns,
    barmode="group",
    log_y=True,
    text_auto=True
)

# %%
temp = gap[gap["year"] == 2007]
temp

px.bar(
    temp,
    x="continent",
    y="pop",
    color="country"
)

# %%
px.bar(
    gap,
    x="continent",
    y="pop",
    color="continent",
    animation_frame="year",
    animation_group="country",
    range_y=[0,10000000]   
)
# Out:
# <div>                            <div id="f717ae73-8628-423f-8ba6-d992c65dbab3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f717ae73-8628-423f-8ba6-d992c65dbab3")) {                    Plotly.newPlot(                        "f717ae73-8628-423f-8ba6-d992c65dbab3",                        [{"alignmentgroup":"True","hovertemplate":"continent=%{x}\u003cbr\u003eyear=1952\u003cbr\u003epop=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","ids":["Afghanistan","Bahrain","Bangladesh","Cambodia","China","Hong Kong, China","India","Indonesia","Iran","Iraq","Israel","Japan","Jordan","Korea, Dem. Rep.","Korea, Rep.","Kuwait","Lebanon","Malaysia","Mongolia","Myanmar","Nepal","Oman","Pakistan","Philippines","Saudi Arabia","Singapore","Sri Lanka","Syria","Taiwan","T
# ...

# %% [markdown]
# # Race Bar Charts in utube

# %% [markdown]
# # Histogram

# %%
px.histogram(
    df,
    x = "lifeExp",
    text_auto=True,
    nbins=10
    
)

# %%
px.histogram(
    iris ,
    x = "sepal_length",
    color="species",
    nbins=30,
    text_auto=True
)

# %% [markdown]
# # Pie Chart

# %%
temp = gap[(gap["year"] == 2007) & (gap["continent"] == "Europe")]
px.pie(
    temp,
    values="pop",
    names="country"
)

# %% [markdown]
# # SunBurst

# %%
df = gap[gap["year"] == 2007]
df
px.sunburst(
    df,
    path=["continent" , "country"] ,
    values = "pop",
    color="lifeExp"
)

# %%
px.sunburst(
    tips,
    path=["sex","smoker","day","time"],
    values="total_bill",
    color="size"
)

# %% [markdown]
# # TreeMap

# %%
df = gap[gap["year"] == 2007]
px.treemap(
    df,
    path=[px.Constant("World") , "continent" , "country"] , values="pop" , color="lifeExp"
)

# %% [markdown]
# # Heapmap

# %%
# df = tips.pivot_table(index="day" , columns="sex" , values="total_bill" ,aggfunc="sum" )
df = gap.pivot_table(
    index="year",
    columns="continent",
    values = "lifeExp",
    aggfunc="mean"
)

px.imshow(
    df
)

# %%
df = gap[gap["year"] == 2007]
px.scatter_3d(
    df,
    x="lifeExp",
    y="pop",
    z="gdpPercap",
    log_y=True,
    color="continent",
    hover_name="country"
    
)

# %%
px.scatter_matrix(
    iris,
    dimensions=["sepal_length" , "sepal_width" , "petal_length" , "petal_width"],
    color="species"
)

# %% [markdown]
# # Plotly express Docoumentaition
