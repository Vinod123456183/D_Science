# %%
import pandas as pd

# %%
df=  pd.read_csv('customer.csv',header=0)

# %%
df.tail(3)
# Out:
#     age  gender review education purchased
# 47   38  Female   Good        PG       Yes
# 48   39  Female   Good        UG       Yes
# 49   25  Female   Good        UG        No

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # sql k jitne operation db sare operation can be done here

# %%
list(df.columns)
# Out:
# ['age', 'gender', 'review', 'education', 'purchased']

# %%
# Agar Koi specific column select krna h toh

df['education'] #yahan pr ek hi select hota h 

type(df['education'])

# series is equivalent to a list


# pandas me hr ek row ya hr ek column (singele col or row return series)
# Out:
# pandas.core.series.Series

# %%
list(df['education'])

# list me index nahi dikhata h but
# Out:
# ['School',
#  'UG',
#  'PG',
#  'PG',
#  'UG',
#  'School',
#  'School',
#  'School',
#  'UG',
#  'UG',
#  'UG',
#  'UG',
#  'School',
#  'School',
#  'PG',
#  'UG',
#  'UG',
#  'UG',
#  'School',
#  'PG',
#  'School',
#  'PG',
#  'PG',
#  'School',
#  'PG',
#  'School',
#  'PG',
#  'PG',
#  'School',
#  'UG',
#  'UG',
#  'School',
#  'UG',
#  'PG',
#  'School',
#  'School',
#  'UG',
#  'PG',
#  'School',
#  'PG',
#  'School',
#  'PG',
#  'PG',
#  'PG',
#  'UG',
#  'PG',
#  'PG',
#  'PG',
#  'UG',
#  'UG']

# %% [markdown]
# # list me index nahi dikhata h but

# %% [markdown]
# # sereis me index ddikhata hai

# %%
df['education']
# Out:
# 0     School
# 1         UG
# 2         PG
# 3         PG
# 4         UG
# 5     School
# 6     School
# 7     School
# 8         UG
# 9         UG
# 10        UG
# 11        UG
# 12    School
# 13    School
# 14        PG
# 15        UG
# 16        UG
# 17        UG
# 18    School
# 19        PG
# 20    School
# 21        PG
# 22        PG
# 23    School
# 24        PG
# 25    School
# 26        PG
# 27        PG
# 28    School
# 29        UG
# 30        UG
# 31    School
# 32        UG
# 33        PG
# 34    School
# 35    School
# 36        UG
# 37        PG
# 38    School
# 39        PG
# 40    School
# 41        PG
# 42        PG
# 43        PG
# 44        UG
# 45        PG
# 46        PG
# 47        PG
# 48        UG
# 49        UG
# Name: education, dtype: object

# %%
df[['education']]
# Out:
#    education
# 0     School
# 1         UG
# 2         PG
# 3         PG
# 4         UG
# 5     School
# 6     School
# 7     School
# 8         UG
# 9         UG
# 10        UG
# 11        UG
# 12    School
# 13    School
# 14        PG
# 15        UG
# 16        UG
# 17        UG
# 18    School
# 19        PG
# 20    School
# 21        PG
# 22        PG
# 23    School
# 24        PG
# 25    School
# 26        PG
# 27        PG
# 28    School
# 29        UG
# 30        UG
# 31    School
# 32        UG
# 33        PG
# 34    School
# 35    School
# 36        UG
# 37        PG
# 38    School
# 39        PG
# 40    School
# 41        PG
# 42        PG
# 43        PG
# 44        UG
# 45        PG
# 46        PG
# 47        PG
# 48        UG
# 49        UG

# %%
type(df[['education']])
# Out:
# pandas.core.frame.DataFrame

# %%
# bina list ke paas kre ek col ka naam toh it will return sereis but list  me paas kre toh become dataframe

# %% [markdown]
# # select multiple column in pandas => paas list

# %%
df[['education','purchased','age']]
# Out:
#    education purchased  age
# 0     School        No   30
# 1         UG        No   68
# 2         PG        No   70
# 3         PG        No   72
# 4         UG        No   16
# 5     School       Yes   31
# 6     School        No   18
# 7     School       Yes   60
# 8         UG        No   65
# 9         UG       Yes   74
# 10        UG       Yes   98
# 11        UG       Yes   74
# 12    School        No   51
# 13    School        No   57
# 14        PG       Yes   15
# 15        UG        No   75
# 16        UG       Yes   59
# 17        UG       Yes   22
# 18    School        No   19
# 19        PG       Yes   97
# 20    School       Yes   57
# 21        PG        No   32
# 22        PG       Yes   18
# 23    School        No   96
# 24        PG       Yes   16
# 25    School        No   57
# 26        PG        No   53
# 27        PG        No   69
# 28    School        No   48
# 29        UG       Yes   83
# 30        UG        No   73
# 31    School       Yes   22
# ...

# %% [markdown]
# #  Dtypes

# %%
df.dtypes

# object means String
# Out:
# age           int64
# gender       object
# review       object
# education    object
# purchased    object
# dtype: object

# %%
# df1 = pd.read_excel('',sheet_name=)

# %%
# type(df1)

# %%
# df1.dtypes

# %%
# df1.columns

# %%
# df1[['','']]

# %% [markdown]
# # From Links

# %%
# df2 = pd.read_csv('')
# ..... 
# other same function

# %% [markdown]
# # From html

# %%
df3 = pd.read_html('https://www.basketball-reference.com/leagues/NBA_2015_totals.html')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 df3 = pd.read_html('https://www.basketball-reference.com/leagues/NBA_2015_totals.html')
#
# File /opt/conda/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/io/html.py:1205, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links)
# ...

# %%
pip install lxml
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 67.2 MB/s eta 0:00:00:00:0100:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import lxml

import pandas as pd


url_linkk = pd.read_html('https://www.basketball-reference.com/leagues/NBA_2015_totals.html')

# %%
url_linkk
# Out:
# [      Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
#  0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
#  1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
#  2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
#  3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
#  4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
#  ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
#  670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
#  671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
#  672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
#  673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
#  674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
type(url_linkk)

# because ek hi list me multiple tables ho stkti hai toh it will return in the list
# Out:
# list

# %%
len(url_linkk)
# Out:
# 1

# %%
df4 = url_linkk[0]

# %%
df4
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
df4.head(3)
# Out:
#   Rk        Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  DRB  \
# 0  1    Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79  222
# 1  2  Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9   19
# 2  3  Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199  324
#
#    TRB AST STL BLK TOV   PF  PTS
# 0  301  68  27  22  60  147  398
# 1   28  16  16   7  14   24   94
# 2  523  66  38  86  99  222  537
#
# [3 rows x 30 columns]

# %%
df4.columns

df4.tail(6)
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 669  489      Nick Young  SG  29  LAL  42   0  1000  174  476  ...  .892   17
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#      DRB  TRB  AST  STL BLK  TOV   PF   PTS
# 669   79   96   41   23  11   44   83   563
# 670  284  411  173  124  25  117  171  1071
# 671  170  245  135   86  17   75  115   685
# 672  114  166   38   38   8   42   56   386
# 673  265  362  100   34  49   62  156   472
# 674  319  465  113   18  52   76  205   833
#
# [6 rows x 30 columns]

# %% [markdown]
# #  Convert LLink to Csv Filw

# %%
df5 = df4.to_csv("basket_ball_output.csv")

# %%
pd.read_csv('basket_ball_output.csv')
# Out:
#      Unnamed: 0   Rk          Player Pos Age   Tm   G  GS    MP   FG  ...  \
# 0             0    1      Quincy Acy  PF  24  NYK  68  22  1287  152  ...
# 1             1    2    Jordan Adams  SG  20  MEM  30   0   248   35  ...
# 2             2    3    Steven Adams   C  21  OKC  70  67  1771  217  ...
# 3             3    4     Jeff Adrien  PF  28  MIN  17   0   215   19  ...
# 4             4    5   Arron Afflalo  SG  29  TOT  78  72  2502  375  ...
# ..          ...  ...             ...  ..  ..  ...  ..  ..   ...  ...  ...
# 670         670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  ...
# 671         671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  ...
# 672         672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  ...
# 673         673  491     Cody Zeller   C  22  CHO  62  45  1487  172  ...
# 674         674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  ...
#
#       FT%  ORB  DRB  TRB  AST  STL BLK  TOV   PF   PTS
# ...

# %% [markdown]
# # avoid extra Column as index

# %%
df7=  df4.to_csv("basket_ball_output123.csv",index = 0,columns=None)
