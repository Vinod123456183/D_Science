# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('wine_data.csv')

# %%
df
# Out:
#      1  14.23  1.71  2.43  15.6  127   2.8  3.06   .28  2.29   5.64  1.04  \
# 0    1  13.20  1.78  2.14  11.2  100  2.65  2.76  0.26  1.28   4.38  1.05
# 1    1  13.16  2.36  2.67  18.6  101  2.80  3.24  0.30  2.81   5.68  1.03
# 2    1  14.37  1.95  2.50  16.8  113  3.85  3.49  0.24  2.18   7.80  0.86
# 3    1  13.24  2.59  2.87  21.0  118  2.80  2.69  0.39  1.82   4.32  1.04
# 4    1  14.20  1.76  2.45  15.2  112  3.27  3.39  0.34  1.97   6.75  1.05
# ..  ..    ...   ...   ...   ...  ...   ...   ...   ...   ...    ...   ...
# 172  3  13.71  5.65  2.45  20.5   95  1.68  0.61  0.52  1.06   7.70  0.64
# 173  3  13.40  3.91  2.48  23.0  102  1.80  0.75  0.43  1.41   7.30  0.70
# 174  3  13.27  4.28  2.26  20.0  120  1.59  0.69  0.43  1.35  10.20  0.59
# 175  3  13.17  2.59  2.37  20.0  120  1.65  0.68  0.53  1.46   9.30  0.60
# 176  3  14.13  4.10  2.74  24.5   96  2.05  0.76  0.56  1.35   9.20  0.61
#
#      3.92  1065
# 0    3.40  1050
# 1    3.17  1185
# 2    3.45  1480
# ...

# %%
df = pd.read_csv('wine_data.csv',usecols=[0,1,2])

# %%
# To give column name

df.columns=['Class label', 'Alcohol', 'Malic acid']

# %%
df
# Out:
#      Class label  Alcohol  Malic acid
# 0              1    13.20        1.78
# 1              1    13.16        2.36
# 2              1    14.37        1.95
# 3              1    13.24        2.59
# 4              1    14.20        1.76
# ..           ...      ...         ...
# 172            3    13.71        5.65
# 173            3    13.40        3.91
# 174            3    13.27        4.28
# 175            3    13.17        2.59
# 176            3    14.13        4.10
#
# [177 rows x 3 columns]

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(13, 5))

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(13, 5))


# note kde plot me x = df[] ese bhi le skte h pr nahi lna


sns.kdeplot(df['Class label'] , ax=ax1, color='blue', fill=0 )
sns.kdeplot(df['Malic acid'] , ax=ax1, color='red', fill=0 )


sns.kdeplot(df['Malic acid'] , ax=ax2, color='blue', fill=0 )
sns.kdeplot(df['Alcohol'] , ax=ax2, color='red', fill=0 )
sns.kdeplot(df['Class label'] , ax=ax2, color='green', fill=0 )
# Out:
# <AxesSubplot: xlabel='Malic acid', ylabel='Density'>

# %%
# we can use different differnt kde 


fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(13, 5))


sns.kdeplot(df['Class label'] , ax=ax1, color='blue', fill=0 )
sns.kdeplot(df['Malic acid'] , ax=ax2, color='red', fill=0 )
# Out:
# <AxesSubplot: xlabel='Malic acid', ylabel='Density'>

# %%
color_dict = {1: 'red', 2: 'blue', 3: 'green'}  # Customize colors based on your class labels
# Create a scatter plot with different colors based on 'Class label'

sns.scatterplot(x='Alcohol', y='Malic acid', hue='Class label', palette=color_dict, data=df)

# Set title and labels
plt.title("Scatter Plot : Alcohol vs. Malic acid by Class")
plt.xlabel("Alcohol")
plt.ylabel("Malic acid")

# Display legend outside the plot

# plt.legend(title='Class', bbox_to_anchor=(1.50, 1), loc='upper left')
# Out:
# Text(0, 0.5, 'Malic acid')

# %%
df.shape
# Out:
# (177, 3)

# %%
clr = np.random.rand(177)
sns.scatterplot(x = df['Alcohol'], y= df['Malic acid'] , data=df , c= clr)
# Out:
# <AxesSubplot: xlabel='Alcohol', ylabel='Malic acid'>

# %%
# aagr random color nahi denen ha hume bs 3 color de skte h 

# 1 --  initilize as dictionry 
# 2 -- c ki jagah palette  
cc =  {1: 'red', 2: 'blue', 3: 'green',4:'black'} 
sns.scatterplot(x = df['Alcohol'], y= df['Malic acid'] , data=df , palette = cc,hue='Class label')
# Out:
# <AxesSubplot: xlabel='Alcohol', ylabel='Malic acid'>

# %%
# agar ye show wala box bahar krna h toh legend function se hota h



cc =  {1: 'red', 2: 'blue', 3: 'green',4:'black'} 
sns.scatterplot(x = df['Alcohol'], y= df['Malic acid'] , data=df , palette = cc,hue='Class label')

plt.legend(title='Class', bbox_to_anchor=(1.1, 1.12), loc='upper left')

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
minmax = MinMaxScaler()

# %%
minmax
# Out:
# MinMaxScaler()

# %%
df.columns
# Out:
# Index(['Class label', 'Alcohol', 'Malic acid'], dtype='object')

# %%
df.dtypes
# Out:
# Class label      int64
# Alcohol        float64
# Malic acid     float64
# dtype: object

# %%
minmax.fit(df[['Alcohol','Malic acid']])
# Out:
# MinMaxScaler()

# %%
newdf = minmax.transform(df[['Alcohol','Malic acid']])

# %%
dff = pd.DataFrame(newdf , columns = ['Alcohol' , 'Malic acid' ])

# %%
dff
# Out:
#       Alcohol  Malic acid
# 0    0.571053    0.205534
# 1    0.560526    0.320158
# 2    0.878947    0.239130
# 3    0.581579    0.365613
# 4    0.834211    0.201581
# ..        ...         ...
# 172  0.705263    0.970356
# 173  0.623684    0.626482
# 174  0.589474    0.699605
# 175  0.563158    0.365613
# 176  0.815789    0.664032
#
# [177 rows x 2 columns]

# %%
clrs =  {1: 'red', 2: 'blue', 3: 'green'} 

sns.scatterplot(x = dff['Malic acid'] , y = dff['Alcohol'] , data = dff , color=clrs , hue = 'Alcohol' )
plt.title('Scatter Plot of Malic acid vs Alcohol')
plt.show()

# %%
clrs =  {1: 'red', 2: 'blue', 3: 'green'} 

sns.scatterplot(x = df['Malic acid'] , y = df['Alcohol'] , data = df , color='red'  )
plt.title('Scatter Plot of Malic acid vs Alcohol')
plt.show()

# %%
np.round(df.describe(), 1)
# Out:
#        Class label  Alcohol  Malic acid
# count        177.0    177.0       177.0
# mean           1.9     13.0         2.3
# std            0.8      0.8         1.1
# min            1.0     11.0         0.7
# 25%            1.0     12.4         1.6
# 50%            2.0     13.0         1.9
# 75%            3.0     13.7         3.1
# max            3.0     14.8         5.8

# %%
np.round(dff.describe(), 1)
# Out:
#        Alcohol  Malic acid
# count    177.0       177.0
# mean       0.5         0.3
# std        0.2         0.2
# min        0.0         0.0
# 25%        0.4         0.2
# 50%        0.5         0.2
# 75%        0.7         0.5
# max        1.0         1.0

# %% [markdown]
# # Kde For two data in one grapph

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(10, 4))

# before scaling
ax1.set_title('Before Scaling')
sns.kdeplot(df['Alcohol'], ax=ax1)
sns.kdeplot(df['Malic acid'], ax=ax1)



# after scaling
ax2.set_title('After Standard Scaling')

sns.kdeplot(dff['Alcohol'], ax=ax2)
sns.kdeplot(dff['Malic acid'], ax=ax2)


plt.show()

# %% [markdown]
# # Kde for only one in one graph

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(10, 4))

# before scaling
ax1.set_title('Before Scaling')
sns.kdeplot(df['Alcohol'], ax=ax1)



# after scaling
ax2.set_title('After Standard Scaling')
sns.kdeplot(dff['Alcohol'], ax=ax2 , fill = 1 , color ='red')
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(10, 4))

# before scaling
ax1.set_title('Before Scaling')
sns.kdeplot(df['Malic acid'], ax=ax1 , fill = 1 , color = 'grey')


# after scaling
ax2.set_title('After Standard Scaling')
sns.kdeplot(dff['Malic acid'], ax=ax2 , fill = 1 , color ='red')
plt.show()
